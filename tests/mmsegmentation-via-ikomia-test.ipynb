# %%
# !pip install ikomia
# Out:
# Collecting ikomia
#   Downloading ikomia-0.12.0-cp310-none-manylinux2014_x86_64.whl.metadata (815 bytes)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from ikomia) (3.0.10)
# Collecting setuptools==59.5.0 (from ikomia)
#   Downloading setuptools-59.5.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting numpy<1.24,>=1.20.3 (from ikomia)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: requests<3.0,>=2.28.0 in /opt/conda/lib/python3.10/site-packages (from ikomia) (2.32.3)
# Collecting mlflow==1.30.0 (from ikomia)
#   Downloading mlflow-1.30.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tensorboard<3.0,>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from ikomia) (2.16.2)
# Requirement already satisfied: Pillow>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from ikomia) (10.3.0)
# Requirement already satisfied: tqdm<5.0,>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from ikomia) (4.66.4)
# Requirement already satisfied: matplotlib<4.0,>=3.4.3 in /opt/conda/lib/python3.10/site-packages (from ikomia) (3.7.5)
# Requirement already satisfied: python-dotenv>=0.18.0 in /opt/conda/lib/python3.10/site-packages (from ikomia) (1.0.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ikomia) (6.0.2)
# Requirement already satisfied: semver<4.0,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from ikomia) (3.0.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==1.30.0->ikomia) (8.1.7)
# Collecting cloudpickle<3 (from mlflow==1.30.0->ikomia)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow==1.30.0->ikomia)
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.10/site-packages (from mlflow==1.30.0->ikomia) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==1.30.0->ikomia) (3.1.43)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==1.30.0->ikomia) (3.20.3)
# Collecting pytz<2023 (from mlflow==1.30.0->ikomia)
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging<22 in /opt/conda/lib/python3.10/site-packages (from mlflow==1.30.0->ikomia) (21.3)
# Collecting importlib-metadata!=4.7.0,<6,>=3.7.0 (from mlflow==1.30.0->ikomia)
#   Downloading importlib_metadata-5.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==1.30.0->ikomia) (0.5.0)
# Requirement already satisfied: alembic<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==1.30.0->ikomia) (1.13.3)
# Collecting docker<7,>=4.0.0 (from mlflow==1.30.0->ikomia)
#   Downloading docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting Flask<3 (from mlflow==1.30.0->ikomia)
#   Downloading flask-2.3.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==1.30.0->ikomia) (1.14.1)
# Collecting pandas<2 (from mlflow==1.30.0->ikomia)
#   Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting prometheus-flask-exporter<1 (from mlflow==1.30.0->ikomia)
#   Downloading prometheus_flask_exporter-0.23.1-py3-none-any.whl.metadata (19 kB)
# Collecting querystring-parser<2 (from mlflow==1.30.0->ikomia)
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Collecting sqlalchemy<2,>=1.4.0 (from mlflow==1.30.0->ikomia)
#   Downloading SQLAlchemy-1.4.54-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting gunicorn<21 (from mlflow==1.30.0->ikomia)
#   Downloading gunicorn-20.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0,>=3.4.3->ikomia) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0,>=3.4.3->ikomia) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0,>=3.4.3->ikomia) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0,>=3.4.3->ikomia) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0,>=3.4.3->ikomia) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0,>=3.4.3->ikomia) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.28.0->ikomia) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.28.0->ikomia) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.28.0->ikomia) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.28.0->ikomia) (2024.8.30)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard<3.0,>=2.5.0->ikomia) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard<3.0,>=2.5.0->ikomia) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<3.0,>=2.5.0->ikomia) (3.6)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard<3.0,>=2.5.0->ikomia) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<3.0,>=2.5.0->ikomia) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<3.0,>=2.5.0->ikomia) (3.0.4)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic<2->mlflow==1.30.0->ikomia) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic<2->mlflow==1.30.0->ikomia) (4.12.2)
# Requirement already satisfied: pyjwt>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==1.30.0->ikomia) (2.8.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==1.30.0->ikomia) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==1.30.0->ikomia) (0.9.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/conda/lib/python3.10/site-packages (from docker<7,>=4.0.0->mlflow==1.30.0->ikomia) (1.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<3->mlflow==1.30.0->ikomia) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<3->mlflow==1.30.0->ikomia) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask<3->mlflow==1.30.0->ikomia) (1.8.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow==1.30.0->ikomia) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow==1.30.0->ikomia) (3.19.2)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from prometheus-flask-exporter<1->mlflow==1.30.0->ikomia) (0.20.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<2,>=1.4.0->mlflow==1.30.0->ikomia) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<3.0,>=2.5.0->ikomia) (2.1.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==1.30.0->ikomia) (5.0.1)
# Downloading ikomia-0.12.0-cp310-none-manylinux2014_x86_64.whl (147.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.1/147.1 MB 2.4 MB/s eta 0:00:0000:0100:02
# Downloading mlflow-1.30.0-py3-none-any.whl (17.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 4.4 MB/s eta 0:00:0000:01:00:01
# Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 40.4 MB/s eta 0:00:00
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 75.6 MB/s eta 0:00:00:00:0100:01
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 10.0 MB/s eta 0:00:00
# Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 9.8 MB/s eta 0:00:00
# Downloading flask-2.3.3-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 kB 7.1 MB/s eta 0:00:00
# Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.6 MB/s eta 0:00:00
# Downloading importlib_metadata-5.2.0-py3-none-any.whl (21 kB)
# Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 81.9 MB/s eta 0:00:00:00:0100:01
# Downloading prometheus_flask_exporter-0.23.1-py3-none-any.whl (18 kB)
# Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 27.3 MB/s eta 0:00:00
# Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Downloading SQLAlchemy-1.4.54-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.2 MB/s eta 0:00:00
# Installing collected packages: pytz, sqlalchemy, setuptools, querystring-parser, numpy, importlib-metadata, cloudpickle, pandas, gunicorn, Flask, docker, databricks-cli, prometheus-flask-exporter, mlflow, ikomia
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.30
#     Uninstalling SQLAlchemy-2.0.30:
#       Successfully uninstalled SQLAlchemy-2.0.30
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.0.0
#     Uninstalling setuptools-70.0.0:
#       Successfully uninstalled setuptools-70.0.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.0
#     Uninstalling importlib-metadata-7.0.0:
#       Successfully uninstalled importlib-metadata-7.0.0
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.0.0
#     Uninstalling cloudpickle-3.0.0:
#       Successfully uninstalled cloudpickle-3.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.0.3
#     Uninstalling Flask-3.0.3:
#       Successfully uninstalled Flask-3.0.3
#   Attempting uninstall: docker
#     Found existing installation: docker 7.1.0
#     Uninstalling docker-7.1.0:
#       Successfully uninstalled docker-7.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albucore 0.0.17 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.17 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 17.0.0 which is incompatible.
# arviz 0.20.0 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# bayesian-optimization 1.5.1 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# beatrix-jupyterlab 2024.66.154055 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.5 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# blis 1.0.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.23.5 which is incompatible.
# cesium 0.12.3 requires numpy<3.0,>=2.0, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.87 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# conda 24.9.0 requires packaging>=23.0, but you have packaging 21.3 which is incompatible.
# conda 24.9.0 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# dask 2024.9.1 requires cloudpickle>=3.0.0, but you have cloudpickle 2.2.1 which is incompatible.
# dask-expr 1.1.15 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# featuretools 1.31.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# featuretools 1.31.0 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 17.0.0 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.54 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# mizani 0.11.4 requires pandas>=2.1.0, but you have pandas 1.5.3 which is incompatible.
# opentelemetry-api 1.25.0 requires importlib-metadata<=7.1,>=6.0, but you have importlib-metadata 5.2.0 which is incompatible.
# plotnine 0.13.6 requires pandas<3.0.0,>=2.1.0, but you have pandas 1.5.3 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.23.5 which is incompatible.
# pyldavis 3.4.1 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# woodwork 0.31.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# woodwork 0.31.0 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# xarray 2024.9.0 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# xarray 2024.9.0 requires packaging>=23.1, but you have packaging 21.3 which is incompatible.
# xarray 2024.9.0 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# yapf 0.40.2 requires importlib-metadata>=6.6.0, but you have importlib-metadata 5.2.0 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed Flask-2.3.3 cloudpickle-2.2.1 databricks-cli-0.18.0 docker-6.1.3 gunicorn-20.1.0 ikomia-0.12.0 importlib-metadata-5.2.0 mlflow-1.30.0 numpy-1.23.5 pandas-1.5.3 prometheus-flask-exporter-0.23.1 pytz-2022.7.1 querystring-parser-1.2.4 setuptools-59.5.0 sqlalchemy-1.4.54

# %%
from ikomia.dataprocess.workflow import Workflow

# Init your workflow
wf = Workflow()

# Add algorithm
segmentor = wf.add_task(name="infer_mmlab_segmentation", auto_connect=True)

segmentor.set_parameters({
        "model_name": "pspnet",
        "model_config": "pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py",
        "cuda": "True",
    })


# Run the workflow on image
wf.run_on(url="https://github.com/open-mmlab/mmsegmentation/blob/main/demo/demo.png?raw=true")

# %%
from ikomia.core import IODataType
from ikomia.utils.displayIO import display

from PIL import ImageShow
ImageShow.register(ImageShow.IPythonViewer(), 0)

# Display the results
display(segmentor.get_image_with_mask())

# %%
# Display legend
results = segmentor.get_results()
display(results.get_legend())

# %%
from ikomia.dataprocess.workflow import Workflow

# Init your workflow
wf = Workflow()

# Add algorithm
segmentor = wf.add_task(name="infer_mmlab_segmentation", auto_connect=True)

# Get list of possible models (model_name, model_config)
models = segmentor.get_model_zoo()

for model in models:
    print(model)
